# %%
import math

class Cylinder:
    def __init__(self, radius, height):
        self.radius = radius
        self.height = height

    def surface_area(self):
        return 2 * math.pi * self.radius * self.height + 2 * math.pi * (self.radius ** 2)

    def volume(self):
        return math.pi * (self.radius ** 2) * self.height
try:
    r, h = map(float, input().split())
    c = Cylinder(r, h)
    print(f"dtbm: {c.surface_area():.2f}")
    print(f"tt: {c.volume():.2f}")
except ValueError:
    pass
# Out:
# dtbm: 226.19
# tt: 251.33
