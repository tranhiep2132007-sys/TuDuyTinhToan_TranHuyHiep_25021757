# %%
a = tuple(map(int, input().split()))
k = int(input())
b =[]
if  k >= len (a):
    print(a)
else:
    for i in range(k,len(a)):
        b.append(a[i])
    for i in range(k):
        b.append(a[i])
    c = tuple(b)
    print(c)
# Out:
# (5, 6)
