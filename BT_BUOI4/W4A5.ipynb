# %%
n = int(input())
d = 0
a = list(map(int,input().split()))
for i in range(n):
    if a[i] == 42:
        print("I′ve found the meaning of life!")
        d = 1
        break
if d == 0:
    print("It's a joke!")
# Out:
# It's a joke!
