# %%
import math 
def sum(n) -> int:
    t = 0
    for i in range(1,math.floor(n)+1):
        if n % i == 0:
            t = t + i
    return t
a, b = map(int, input().split())
if sum(a) == sum(b):
    print("True")
else:
    print("Fasle")
# Out:
# True
